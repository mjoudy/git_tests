# %%
#this is a notebook for test git commands. Maybe has been used for other purposes in future.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sc

# %%
x = np.array([1,2,3,4,5])
y = np.sinc(x)

# %%
y
# Out:
# array([ 3.89817183e-17, -3.89817183e-17,  3.89817183e-17, -3.89817183e-17,
#         3.89817183e-17])

# %%
plt.plot(x,y)

# %%
plt.plot(y,x)
